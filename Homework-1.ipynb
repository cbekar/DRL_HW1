# %% [markdown]
# # Homework 1
#
# In this homework you will be implementing the followings:
# - Modeling an MDP             **(30)**
# - Dynamic programming methods **(20)**
# - Tabular Methods             **(20)**
# - Approximate Methods         **(30)**
#
# This notebook is like an interface of your implementations, you can visualize and observe your agents and your MDP. You can still change some of the cells below in order to experiment with your implementations but remember that you don't need to modify this notebook.

# %% [markdown]
# ## 1. Modeling your MDP
# In this section of the homework, you will be implementing an MDP for the given dynamics of the environment. You need to code the missing part of the gridworld module in the env folder. In order to model the MDP, you are being asked to construct a transition table(transition_map) for the MDP that keeps the transition probabilities, reward values and terminations for each neighbor of all the reachable states.
#
#
# ```
# transition_map[state][action] -> [(probability, neighboor_state, reward, termination), ...]
#
# ```
#
# ### MDP
#
# - Any tile on the grid has four adjacent tiles if it is not at the border.
# - From all the reachable states(none wall tiles) it is only allowed to transition to its neighbour states(adjacent tiles) or itself.
# - In a reachable tile, an agent is expected to transition to its targeted tile by the given action with 0.95 probability and all the other neighbour tiles with the 0.05 probability(uniformly).
# - If a tile has a termination equals to 1, the episode is expected to be finished.
# - Reward and termination values are given for all the tile types so you don't need to define them.

# %% [markdown]
# You may want to check out some of the [gym environments](https://github.com/openai/gym/tree/master/gym/envs/toy_text) for help.

# %%
# In order to use modified modules without restarting
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### Grid World (Random agent)

# %%
from blg604ehw1 import GridWorldEnv
import random
import time
env = GridWorldEnv()
eps = 0
iteration = 0
for i in range(100):
    state, reward, done, info = env.step(random.randint(0, 3))
    iteration += 1
    env.render(mode="notebook", info="Episode: {}, Step: {}".format(eps, iteration))
    if done:
        env.reset()
        eps += 1
        iteration = 0
env.renderer.animate("js")
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img0f903cb6084549f59ce2f66b9d11e174">
#     <br>
#     <input id="_anim_slider0f903cb6084549f59ce2f66b9d11e174" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim0f903cb6084549f59ce2f66b9d11e174.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim0f903cb6084549f59ce2f66b9d11e174.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select0f903cb6084549f59ce2f66b9d11e174" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0f903cb6084549f59ce2f66b9d11e174";
#     var slider_id = "_anim_slider0f903cb6084549f59ce2f66b9d11e174";
#     var loop_select_id = "_anim_loop_select0f903cb6084549f59ce2f66b9d11e174";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAAPYQAAD2EBqD+naQAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAAEWlJREFUeJzt3W1slfXdwPEf9lgpSCfyMGRasTpF\
# ZghN3ILN5kDwhRjK9M7MNDqIbIgYIT5si4p1bE6Nxi3qpOqm2IiJSwQ3GBjDC9lgOtQNZQ/GOhsX\
# spVECgwJZQXa+8Vuz9bxVKfd9Sv355Pw4jpc/Z/fuUJCv7kezoDu7u7uAAAASOyYogcAAAA4EuEC\
# AACkJ1wAAID0hAsAAJCecAEAANITLgAAQHrCBQAASE+4AAAA6QkXAAAgPeECAACkJ1wAAID0hAsA\
# AJCecAEAANITLgAAQHrCBQAASE+4AAAA6QkXAAAgPeECAACkJ1wAAID0hAsAAJCecAEAANITLgAA\
# QHrCBQAASE+4AAAA6QkXAAAgPeECAACkJ1wAAID0hAsAAJCecAEAANITLgAAQHrCBQAASE+4AAAA\
# 6QkXAAAgPeECAACkJ1wAAID0SkUPwOE1NzcXPQIAAB/BzJkzix7hqOCMCwAAkJ5wAQAA0hMuAABA\
# eu5xAehDu3fvjs7OzqLHoJ+qrKyMQYMGFT0GQArCBaCP7N69O375y19GRUVF0aPQT+3fvz/OP/98\
# 8QIQwgWgz3R2dkZFRUU0NDTE0KFDix6Hfmb79u2xYsWK6OzsFC4AIVwA+tzQoUNjxIgRRY8BAP2a\
# m/MBAID0hAsAAJCecAEAANITLgAAQHrCBaCf++tf/xp1dXXx1ltv9dl7NDY2xg033NBn6wPAkXiq\
# GECBGhsbY+XKlQe8Xl9fHw8//HCv1vjkJz8Za9asiRNOOOHjHq/PtbW1xV133RWvvfZaVFVVxfTp\
# 0+P666+PUqn3/z1t27YtmpqaYv369dHe3h7V1dVx5plnxpw5c2LChAkREVFXVxff//73Y/LkyX31\
# UQ7rxz/+caxbty5aWlqiVCrFunXrCpkDoD8TLgAFq6+vj0WLFvV4rbKystc/X1FREcOHD/+4x+pz\
# +/fvj/nz58ewYcPiySefjPfeey9uv/32KJVKcf311/d6nZtvvjn27dsX3/nOd+JTn/pUbNu2LTZs\
# 2BA7duzow+k/nL1798aFF14Y48ePj5/+9KdFjwPQLwkXgIJVVlYeNjzq6urilltuiV/84hfxm9/8\
# JoYPHx4LFiyICy+8MCL+canYxRdfHM8880ycddZZsXPnzrjnnnvi5Zdfjo6Ojhg5cmTMnj07ZsyY\
# ERERb7/9dtx3332xadOmGDhwYEyZMiVuuumm8pcc7t+/P37wgx/Ez372s6ioqIgvfelL0d3d3WOm\
# rq6uWLJkSSxfvjza29ujpqYmvv71r5dn6o2XX345Wltb45FHHolhw4bFWWedFfPmzYsHH3ww5s6d\
# G8cee+wR13j//fdj48aN8aMf/SjOPffciIgYPXp0nHPOOeV9pk2bFhERN954Y0REnHTSSbF69eqI\
# iHjxxRfjsccei9bW1hgxYkRMnz49Zs+eXT7jc6Rj31vXXnttRESsWLHiQ/0cAP/kHheAfqCpqSmm\
# TJkSP/nJT+Kiiy6KW265JVpbWw+67+LFi6O1tTV++MMfxvLly+PWW28tX0bW0dER8+bNiyFDhsTS\
# pUvj3nvvjQ0bNsQ999xT/vmnnnoqVq5cGd/+9rfjiSeeiL/97W/x4osv9niPJ554IlatWhW33XZb\
# PPvss3HllVfGwoUL47XXXivvM23atHjkkUcO+Zk2bdoUZ5xxRgwbNqz8Wn19fezatSveeeedXh2X\
# qqqqGDRoUKxduzY6OzsPus/SpUsjImLRokWxZs2a8vZvf/vbaGxsjMsvvzyWLVsWCxcujBUrVsTj\
# jz/e4+ePdOy/9rWvRWNjY6/mBeA/J1wACrZu3bqor6/v8efff3meOnVqXHrppXHqq

# %% [markdown]
# ## 2. Dynamic Programming Methods
#
# Now, you have an MDP whose transition and reward functions are known, you can start optimizing your agent. For this instance, you will be implementing dynamic programming methods namely Policy Iteration and Value Iteration.
# Then you can visualize your agents.

# %%
from blg604ehw1 import GridWorldEnv
from blg604ehw1 import PolicyIteration
from blg604ehw1 import ValueIteration

def train_dp(agent, env):
    agent.optimize(gamma=1.0, epsilon=0.001)
    done = False
    state = env.reset()
    while (not done):
        act = agent.policy(state)
        state, reward, done, _ = env.step(act)
        env.render(mode="notebook")
    return env.renderer.animate("js")

# %% [markdown]
# Policy Iteration

# %%
train_dp(PolicyIteration(env.nA, env.nS, env.P), GridWorldEnv())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgfd5b844ae0a44966bdf36e4216ac46f7">
#     <br>
#     <input id="_anim_sliderfd5b844ae0a44966bdf36e4216ac46f7" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animfd5b844ae0a44966bdf36e4216ac46f7.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animfd5b844ae0a44966bdf36e4216ac46f7.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectfd5b844ae0a44966bdf36e4216ac46f7" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgfd5b844ae0a44966bdf36e4216ac46f7";
#     var slider_id = "_anim_sliderfd5b844ae0a44966bdf36e4216ac46f7";
#     var loop_select_id = "_anim_loop_selectfd5b844ae0a44966bdf36e4216ac46f7";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABEJJREFUeJzt2LFNHUEYRlGetX3QysYOoYDtgJ62\
# AAgdbytUMhRg34BgNO+Zcwr49SUjXc1tjDGeAAD4y6/VAwAA7pVQAgAIQgkAIAglAIAglAAAglAC\
# AAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhCCQAg\
# CCUAgCCUAACCUAIACEIJACAIJQCAIJQAAMK2esAjO89z9QQAmOo4jtUTlvKjBAAQhBIAQBBKAABB\
# KAEABKEEABCEEgBAEEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAAShBAAQhBIAQBBKAABBKAEABKEE\
# ABCEEgBAEEoAAEEoAQAEoQQAELbVA/i3fd9XT4CHd13XtNveKN/x8vwy9f7b+Tb1/k/mRwkAIAgl\
# AIAglAAAglACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAA\
# glACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAMK2egAA/O8+Pj+m3r+erqn3fzI/SgAA\
# QSgBAAShBAAQhBIAQBBKAABBKAEABKEEABCEEgBAEEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAASh\
# BAAQhBIAQBBKAABBKAEABKEEABCEEgBAEEoAAEEoAQCEbfUAgFn2fV89AXhwfpQAAIJQAgAIQgkA\
# IAglAIAglAAAglACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAg\
# lAAAglACAAhCCQAgCCUAgCCUAACCUAIACEIJACBsqwcAzHJd17Tb+75Puw3cDz9KAABBKAEABKEE\
# ABCEEgBAEEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAAShBAAQhBIAQBBKAABBKAEABKEEABCEEgBA\
# EEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAIRt9QC4J69/nqfdfv/9Oe02AHP4UQIACEIJACAIJQCA\
# IJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQ\
# AgAIQgkAIAglAIAglAAAglACAAhCCQAgCCUAgHAbY4zVIx7VeZ6rJwDAVMdxrJ6wlB8lAIAglAAA\
# glACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhC\
# CQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAMJtjDFWjwAAuEd+lAAAglACAAhCCQAgCCUAgCCU\
# AACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhCCQAgCCUAgCCUAACCUAIA\
# CEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhf5HEkK3f+CukAAAAASUVORK5CYII=\
# "
#   frames[1] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABENJREFUeJzt2LFtHDEURVGtMX2olYkdygVMB+pp\
# CrBCx9OKKqELkG7ggOCu95wCPl5C4IK3McZ4AQDgix+rBwAA3CuhBAAQhBIAQBBKAABBKAEABKEE\
# ABCEEgBAEEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAAShBAAQhBIAQBBKAABBKAEABKEEABCEEgBA\
# EEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAIRt9YBHdp7

# %% [markdown]
# #### Value Iteration

# %%
train_dp(ValueIteration(env.nA, env.nS, env.P), GridWorldEnv())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgd0ac571887b1425a86b907a901e678b5">
#     <br>
#     <input id="_anim_sliderd0ac571887b1425a86b907a901e678b5" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animd0ac571887b1425a86b907a901e678b5.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animd0ac571887b1425a86b907a901e678b5.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectd0ac571887b1425a86b907a901e678b5" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd0ac571887b1425a86b907a901e678b5";
#     var slider_id = "_anim_sliderd0ac571887b1425a86b907a901e678b5";
#     var loop_select_id = "_anim_loop_selectd0ac571887b1425a86b907a901e678b5";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABEJJREFUeJzt2LFNHUEYRlGetX3QysYOoYDtgJ62\
# AAgdbytUMhRg34BgNO+Zcwr49SUjXc1tjDGeAAD4y6/VAwAA7pVQAgAIQgkAIAglAIAglAAAglAC\
# AAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhCCQAg\
# CCUAgCCUAACCUAIACEIJACAIJQCAIJQAAMK2esAjO89z9QQAmOo4jtUTlvKjBAAQhBIAQBBKAABB\
# KAEABKEEABCEEgBAEEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAAShBAAQhBIAQBBKAABBKAEABKEE\
# ABCEEgBAEEoAAEEoAQAEoQQAELbVA/i3fd9XT4CHd13XtNveKN/x8vwy9f7b+Tb1/k/mRwkAIAgl\
# AIAglAAAglACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAA\
# glACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAMK2egAA/O8+Pj+m3r+erqn3fzI/SgAA\
# QSgBAAShBAAQhBIAQBBKAABBKAEABKEEABCEEgBAEEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAASh\
# BAAQhBIAQBBKAABBKAEABKEEABCEEgBAEEoAAEEoAQCEbfUAgFn2fV89AXhwfpQAAIJQAgAIQgkA\
# IAglAIAglAAAglACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAg\
# lAAAglACAAhCCQAgCCUAgCCUAACCUAIACEIJACBsqwcAzHJd17Tb+75Puw3cDz9KAABBKAEABKEE\
# ABCEEgBAEEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAAShBAAQhBIAQBBKAABBKAEABKEEABCEEgBA\
# EEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAIRt9QC4J69/nqfdfv/9Oe02AHP4UQIACEIJACAIJQCA\
# IJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQ\
# AgAIQgkAIAglAIAglAAAglACAAhCCQAgCCUAgHAbY4zVIx7VeZ6rJwDAVMdxrJ6wlB8lAIAglAAA\
# glACAAhCCQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhC\
# CQAgCCUAgCCUAACCUAIACEIJACAIJQCAIJQAAMJtjDFWjwAAuEd+lAAAglACAAhCCQAgCCUAgCCU\
# AACCUAIACEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhCCQAgCCUAgCCUAACCUAIA\
# CEIJACAIJQCAIJQAAIJQAgAIQgkAIAglAIAglAAAglACAAhf5HEkK3f+CukAAAAASUVORK5CYII=\
# "
#   frames[1] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABENJREFUeJzt2LFtHDEURVGtMX2olYkdygVMB+pp\
# CrBCx9OKKqELkG7ggOCu95wCPl5C4IK3McZ4AQDgix+rBwAA3CuhBAAQhBIAQBBKAABBKAEABKEE\
# ABCEEgBAEEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAAShBAAQhBIAQBBKAABBKAEABKEEABCEEgBA\
# EEoAAEEoAQAEoQQAEIQSAEAQSgAAQSgBAIRt9YBHdp7

# %% [markdown]
# ## 3. Tabular Methods
#
# What if you don't know the transition function or the reward function of the MDP. This is generally the case for most of the environments. This is where you need to optimize your agents via sampling or simply exploring the environment.
#
# In this section, you will be implementing tabular Q learning and Sarsa methods to optimally control your agents in the same gridworld environment. You can also visualize the learning process and observe how the value propagates through the adjacent states.

# %%
from collections import namedtuple
from blg604ehw1 import QAgent
from blg604ehw1 import SarsaAgent
from blg604ehw1 import GridWorldEnv

QTransition = namedtuple("QTransition", "state action reward next_state terminal")
SarsaTransition = namedtuple("SarsaTransition", "state action reward next_state next_action terminal")

# %%
EPSILON = 0.2
ALPHA = 0.5
EPISODES = 100
MAX_LEN = 200
GAMMA = 0.99

def iter_episode(env, agent, test=False):
    eps_reward = 0.0
    policy = agent.greedy_policy if test else agent.soft_policy
    state = env.reset()
    action = policy(state)
    td_error = 0
    for i in range(MAX_LEN):       
        next_state, reward, done, _ = env.step(action)
        next_action = policy(next_state)
        if isinstance(agent, QAgent):
            transition = QTransition(state, action, reward, next_state, done)
        elif isinstance(agent, SarsaAgent):
            transition = SarsaTransition(state, action, reward, next_state, next_action, done)
        if not test:
            td_error += agent.update(transition, ALPHA, GAMMA)
        eps_reward += reward
        state = next_state
        action = next_action
        if done:
            break
            
    episode_length = i
    return episode_length, eps_reward, abs(td_error)

# %%
def visualize_test(env, agent):
    env.renderer.reset_buffer()
    eps_reward = 0.0
    state = env.reset()
    for i in range(MAX_LEN):
        action = agent.greedy_policy(state)
        state, reward, done, _ = env.step(action)
        env.render(mode="notebook")
        eps_reward += reward
        if done:
            break
            
    episode_length = i
    return episode_length, eps_reward, 0

# %%
def train(agent, env):
    _, _, td = iter_episode(agent, env, test=False)
    eps_length, eps_reward, _ = iter_episode(agent, env, test=True)
    return eps_reward, eps_length, float(td)

# %% [markdown]
# #### Training

# %%
REPEAT = 25
q_logs = [[train(env, agent) for i in range(EPISODES)] for env, agent in [(GridWorldEnv(), QAgent(4))]*REPEAT]
sarsa_logs = [[train(env, agent) for i in range(EPISODES)] for env, agent in [(GridWorldEnv(), SarsaAgent(4))]*REPEAT]

# %% [markdown]
# #### Agent Comparison
# **Note:** You may want to rerun the cell below if plots are mixed together.

# %%
from blg604ehw1 import comparison
plot_texts = [
    [
        "Episodic Reward",
        "episode",
        "reward"
    ],
    [
        "Episode Length",
        "episode",
        "length"
    ],
    [
        "Td Error",
        "episode",
        "td"
    ]
]
comparison((q_logs, "Q agent"), (sarsa_logs, "Sarsa agent"), texts=plot_texts)

# %% [markdown]
# #### Greedy Policy After Training

# %%
#agent = QAgent(4)
agent = SarsaAgent(4)
env = GridWorldEnv()
[train(env, agent) for i in range(EPISODES)]
visualize_test(env, agent)
env.renderer.animate()

# %% [markdown]
# ####  What's under the hood?

# %%
from copy import deepcopy
from collections import defaultdict
import numpy as np 
agent = QAgent(4)
#agent= SarsaAgent(4)
env = GridWorldEnv()
value_buffer = []
for i in range(EPISODES*2):
    iter_episode(env, agent)
    value_buffer.append(deepcopy(agent.values))
    
env.renderer.analysis(value_buffer)

# %% [markdown]
# ## 4. Approximate Methods
# When the state space is too large or it's continuous it becomes difficult to use tabular methods. This is where approximation can be handy. In this section, you will be implementing approximate Q learning, approximate Sarsa and least-square temporal difference method where the value function is approximated with a linear function or with a linear combination of RBFs on the Cart Pole environment. The objective of the environment is to balance the rod by moving the cart along the x-axis.

# %%
import gym
import numpy as np
from blg604ehw1 import animater

# %% [markdown]
# ### Cart Pole (Random agent)

# %%
import warnings
with warnings.catch_warnings():      # To catch a simple warning from gym
    warnings.simplefilter("ignore")
    
    env = gym.make("CartPole-v1")
    env.reset()
    buffer = []
    for i in range(60):
        env.step(env.action_space.sample())
        buffer.append(env.render(mode='rgb_array'))
    env.close()    
animater(buffer)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img7ff3ccbcce6c4ad580de37e457c9d82c">
#     <br>
#     <input id="_anim_slider7ff3ccbcce6c4ad580de37e457c9d82c" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim7ff3ccbcce6c4ad580de37e457c9d82c.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim7ff3ccbcce6c4ad580de37e457c9d82c.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select7ff3ccbcce6c4ad580de37e457c9d82c" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7ff3ccbcce6c4ad580de37e457c9d82c";
#     var slider_id = "_anim_slider7ff3ccbcce6c4ad580de37e457c9d82c";
#     var loop_select_id = "_anim_loop_select7ff3ccbcce6c4ad580de37e457c9d82c";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABO1JREFUeJzt3OtpAkEYQNFssIq0YR1pQ2vSNlKH\
# baSNzY9ACHlAHq7jXc8BQQXhA5XrMDtO8zzPdwAQcz96AAD4CwEDIEnAAEgSMACSBAyAJAEDIEnA\
# AEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAED\
# IEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyA\
# JAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACS\
# BAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgS\
# MACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnA\
# AEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAED\
# IEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyA\
# JAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEjajB4A\
# bsXpuP/03HZ3GDAJrIMVGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgcAFfnQED/kfAAEgSMACS\
# BAyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAyAJAGDQba7w+gRIE3AAEgSMACSBAyAJAED\
# IEnAAEgSMACSBAyAJAEDIEnAAEgSMACSBAwWdjruR48AqyRgACQJGABJAgZAkoABkCRgACQJGABJ\
# AgZAkoABkCRgACQJGABJAgZAkoDBANvdYfQIkCdgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoAB\
# kCRgACQJGABJAgYLOh33o0eA1RIwuDD/gwjnIWAAJAkYAEkCBkCSgAGQJGAAJAkY/NI0TT++LfF6\
# 4JWAAZC0GT0ArN3T8+7t/uPDceAksC5WYLCg9/H66jHwdwIGQJKAAZAkYLCgj3te9sDgfKZ5nufR\
# Q0DJJS9v9/WE793MVYjO1FDkc8vSyj+SbiZg5TeJ62IFBtfBHhgASQIGQJKAAZAkYAAkCRgASQIG\
# QJKAAZB0M+fA4FyczYLrYAUGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAk\
# CRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAk\
# YAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKA\
# AZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIG\
# QJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgA\
# SQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQNILFQgugJb3jw4AAAAASUVORK5CYII=\
# "
#   frames[1] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABOtJREF

# %% [markdown]
# ### Approximate Q Learning and Sarsa(Semi-gradient Methods)
# When we approximate the value function one way to optimize the Bellman equation is via Gradient Descent. Yet, as you may remember we don't want to change the target value when optimizing the equation. However, when we take the gradient with respect to parameters it's no longer the case. That's why we only take the gradient with respect to predicted value's parameters and therefore it's also called Semi-Gradient Method.
#
# You will be implementing Sarsa and Q Learning in approximate settings.

# %%
from blg604ehw1 import ApproximateSarsaAgent
from blg604ehw1 import ApproximateQAgent
from collections import namedtuple
from copy import deepcopy

QTransition = namedtuple("QTransition", "state action reward next_state terminal")
SarsaTransition = namedtuple("SarsaTransition", "state action reward next_state next_action terminal")

ALPHA = 0.01
EPISODES = 200
MAX_LEN = 200
GAMMA = 0.99

def iter_episode(env, agent, test=False, iteration=None):
    eps_reward = 0.0
    td_error = 0
    iteration = iteration or 1
    policy = agent.greedy_policy if test else lambda s: agent.e_greedy_policy(s, 0.9/(iteration+1)+0.05)
    state = env.reset()
    action = policy(state)
    for i in range(MAX_LEN):
        next_state, reward, done, _ = env.step(action)
        next_action = policy(state)
        if isinstance(agent, ApproximateQAgent):
            transition = QTransition(state, action, reward, next_state, done)
        elif isinstance(agent, ApproximateSarsaAgent):
            transition = SarsaTransition(state, action, reward, next_state, next_action, done)
        if not test:
            td_error += agent.update(transition, ALPHA, GAMMA)
        eps_reward += reward
        state = next_state
        action = next_action
        if done:
            break
            
    episode_length = i
    return episode_length, eps_reward, abs(td_error)

# %% [markdown]
# **Checkpoints** are important when you are dealing with approximate methods. You can keep the best agent by comparing agents test rewards.

# %%
Checkpoint = namedtuple("Checkpoint", "agent, avg_reward")
checkpoint = Checkpoint(None, 0)
def train(env, agent, i):
    global checkpoint
    _, _, td = iter_episode(env, agent, test=False, iteration=i)
    avg_reward = sum(iter_episode(env, agent, test=True)[1] for i in range(5))/5
    if checkpoint.avg_reward < avg_reward:
        checkpoint = Checkpoint(deepcopy(agent), avg_reward)
    return checkpoint.avg_reward, avg_reward, td  # In CartPole reward is the length

# %% [markdown]
# #### Training
# **NOTE**: You may need to train your agents many times until they learn! Approximate methods are not guaranteed to converge and sometimes they diverge! Remember, the maximum reward is the Episode length (MAX_LEN).

# %%
REPEAT = 50
q_logs = [[train(env, agent, i) for i in range(EPISODES)] 
          for env, agent in [(gym.make("CartPole-v1"), ApproximateQAgent(4, 2))]*REPEAT]
q_checkpoint = checkpoint
checkpoint = Checkpoint(None, 0)
sarsa_logs = [[train(env, agent, i) for i in range(EPISODES)] 
              for env, agent in [(gym.make("CartPole-v1"), ApproximateSarsaAgent(4, 2))]*REPEAT]
sarsa_checkpoint = checkpoint

# %% [markdown]
# #### Comparison

# %%
from blg604ehw1 import comparison
plot_texts = [
    
    [
        "Best Reward",
        "episode",
        "reward"
    ],
    [
        "Episodic Reward",
        "episode",
        "reward"
    ],
    [
        "Td Error",
        "episode",
        "td"
    ]
]
comparison((q_logs, "Semi-Gradient Q agent"), (sarsa_logs, "Semi-Gradient Sarsa agent"), texts=plot_texts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-0e33d068777b> in <module>
#      18     ]
#      19 ]
# ---> 20 comparison((q_logs, "Semi-Gradient Q agent"), (sarsa_logs, "Semi-Gradient Sarsa agent"), texts=plot_texts)
#
# ~/Dropbox/Academic/PhD/Semesters/Spring19/RL/DRL/HWs/BLG6043-HW1-homework/blg604ehw1/env/render.py in comparison(texts, *log_name_pairs)
#     201             min_logs = np.min(smoothed_logs, axis=0)
#     202             plot_texts(title, xlabel, ylabel)
# --> 203             plt.plot(mean_logs, label=name)
#     204             plt.legend()
#     205             plt.fill_between(np.arange(len(mean_logs)), np.minimum(mean_logs+std_logs, max_logs), np.minimum(mean_logs-std_logs, min_logs), alpha=0.4)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
# --> 245                              "shapes {} and {}".format(x.shape, y.shape))
#     246
#     247         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (193,) and (193, 4, 2)

# %%
def visualize_test(env, agent):
    eps_reward = 0.0
    state = env.reset()
    buffer = []
    for i in range(MAX_LEN):
        action = agent.greedy_policy(state)
        state, reward, done, _ = env.step(action)
        buffer.append(env.render(mode='rgb_array'))
        eps_reward += reward
        if done:
            break
            
    episode_length = i
    env.close()
    return buffer
buffer = visualize_test(gym.make("CartPole-v1"), q_checkpoint.agent)
print("Max reward: {}, current best: {}".format(MAX_LEN, q_checkpoint.avg_reward))
animater(buffer)
buffer = visualize_test(gym.make("CartPole-v1"), sarsa_checkpoint.agent)
print("Max reward: {}, current best: {}".format(MAX_LEN, sarsa_checkpoint.avg_reward))
animater(buffer)
# Out:
# Max reward: 200, current best: 196.0
# Max reward: 200, current best: 200.0
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img618a545ca944420e838d8116eda1e8c2">
#     <br>
#     <input id="_anim_slider618a545ca944420e838d8116eda1e8c2" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim618a545ca944420e838d8116eda1e8c2.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim618a545ca944420e838d8116eda1e8c2.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select618a545ca944420e838d8116eda1e8c2" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img618a545ca944420e838d8116eda1e8c2";
#     var slider_id = "_anim_slider618a545ca944420e838d8116eda1e8c2";
#     var loop_select_id = "_anim_loop_select618a545ca944420e838d8116eda1e8c2";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABNNJREFUeJzt3MFNAkEYgFHXUIVtWIdtQE3ShnXQ\
# hm0MZ4wHRdjxY99LOMBh8ycs+XZgh2WMMZ4AIOZ59gAAcA0BAyBJwABIEjAAkgQMgCQBAyBJwABI\
# EjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJ\
# wABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQB\
# AyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQM\
# gCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAA\
# kgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABI\
# EjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJ\
# wABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQB\
# AyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABI2s0eALbi\
# dDx8+/rr/n3lSeAxWIEBkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGEzkb6Tg\
# egIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAk\
# CRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAk\
# YAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGQJKAAZAkYAAkCRgASQIGKzgd\
# D7NHgIcjYAAkCRgASQIGQJKAAZAkYHClZVl+/LjnMWCrBAyApN3sAWArPj73F8/fXo6TJoHHYAUG\
# k3wNGvA7AgYrECu4PQGDFfi6EG5PwGASUYO/WcYYY/YQULT2re0+qnBpM3ch2kdDnXOYeyhfGG0m\
# YOU3if/JCgzm8hsYAEkCBkCSgAGQJGAAJAkYAEkCBkCSgAGQtJl9YHBr9mXBXFZgACQJGABJAgZA\
# koABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJ\
# AgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJ\
# GABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRg\
# ACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoAB\
# kCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZA\
# koABkCRgACSdAQK/KICkpaE/AAAAAElFTkSuQmCC\
# "
#   frames[1] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABMdJREFUeJzt291JA0EYQFFXUoVtWIdtxJpMG9Zh\
# G

# %% [markdown]
# When we approximate the value function things get messy. One of the reason is Bootstrapping. Its also known as "guess from a guess". You actually used it before when you implemented q learning and sarsa(named after "state action reward state' action' "). In the Bellman equation when you use your not yet converged values as the target value, it is bootstrapping. TD uses bootstrapping to update the values at every step rather than the end of an episode. In tabular settings this is quite handy, however, there is a caveat when using it in the approximate settings.
#
# $ TD_{error} \leftarrow (R +  max_{a}V(s', a)\gamma - V(s, a))^2$
#
# Since the value function is parameterized with a parameter vector when you update it, both the predicted value and the target value will be changed while the target should not be changed. This means you won't be able to trap the reward as easily as in the tabular settings.

# %% [markdown]
# ### Least-Square Temporal Difference (LSTDQ)
# Instead of iteratively updating the values you can find the best fitting approximation in one step when you are using a linear approximation. LSTD methods are exactly doing this. In this subsection, you will be implementing LSTDQ method and you will be training it in the same environment.

# %%
from blg604ehw1 import LSTDQ

QTransition = namedtuple("QTransition", "state action reward next_state terminal")
SARSATransition = namedtuple("SARSATransition", "state action reward next_state next_action terminal")

EPISODES = 1000
MAX_LEN = 200
GAMMA = 1
MEMORY_LENGTH = 200
RBF_KERNELS = 50
REPEAT = 10

checkpoint = Checkpoint(None, 0)

def test_one_episode(env ,agent):
    eps_reward = 0.0
    policy = agent.greedy_policy
    state = env.reset()
    for i in range(MAX_LEN):
        action = policy(state)
        state, reward, done, info = env.step(action)
        eps_reward += reward
        if done:
            break
    return eps_reward

def train(env, agent, test=False):
    global checkpoint
    trajectory = []
    rewards = []
    avg_reward = 0
    for iteration in range(EPISODES):
        policy = lambda s: agent.e_greedy_policy(s, 0.9/(iteration+1)+0.05)
        state = env.reset()
        for i in range(MAX_LEN):
            action = policy(state)
            next_state, reward, done, _ = env.step(action) 
            next_action = policy(next_state)
            transition = SARSATransition(state, action, reward, next_state, next_action, done)
            trajectory.append(transition)
            state = next_state
            if done:
                break
        rewards.append((avg_reward, checkpoint.avg_reward))
        
        if len(trajectory) > MEMORY_LENGTH:
            agent.optimize(trajectory, GAMMA)
            trajectory = []
            avg_reward = sum(test_one_episode(env, agent) for i in range(5))/5
             
            if checkpoint.avg_reward < avg_reward:
                checkpoint = Checkpoint(deepcopy(agent), avg_reward)
            
    episode_length = i
    return rewards

# %% [markdown]
# #### Training

# %%
lstdq_log = [train(env, agent) for env, agent in [(gym.make("CartPole-v1"), LSTDQ(4, 2, RBF_KERNELS))]*REPEAT]

# %%
from blg604ehw1 import comparison
plot_texts = [
    [
        "Episodic Test Reward",
        "episode",
        "reward"
    ],
    [
        "Best Reward",
        "episode",
        "reward"
    ]
]
comparison((lstdq_log, "Semi-Gradient Q agent"), texts=plot_texts)

# %% [markdown]
# #### Visualize the agent after training

# %%
buffer = visualize_test(gym.make("CartPole-v1"), checkpoint.agent)
print("Max reward: {}, current best: {}".format(MAX_LEN, checkpoint.avg_reward))
animater(buffer)
# Out:
# Max reward: 200, current best: 200.0
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img5ce95430311a488ca563f9a50a0ec271">
#     <br>
#     <input id="_anim_slider5ce95430311a488ca563f9a50a0ec271" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim5ce95430311a488ca563f9a50a0ec271.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim5ce95430311a488ca563f9a50a0ec271.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select5ce95430311a488ca563f9a50a0ec271" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5ce95430311a488ca563f9a50a0ec271";
#     var slider_id = "_anim_slider5ce95430311a488ca563f9a50a0ec271";
#     var loop_select_id = "_anim_loop_select5ce95430311a488ca563f9a50a0ec271";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABNVJREFUeJzt2+1JQmEYgGFPOIVr1BquoTPpGq1R\
# a7TG248gigj68Hi89bpAEEF4QOX20fNOY4yxAoCYu6UHAIC/EDAAkgQMgCQBAyBJwABIEjAAkgQM\
# gCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAA\
# kgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABI\
# EjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJ\
# wABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQB\
# AyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQM\
# gCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAA\
# kgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABI\
# EjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgCQBAyBJwABIEjAAkgQMgKT10gPA\
# NXs+7r88dr87LDAJXB8bGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRg\
# ACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoAB\
# kCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZA\
# koABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJ\
# AgZAkoABkCRgACQJGPzSNE0/vs3xfOCNgAGQtF56ALh2jy+79/vbzXHBSeC62MDgjD7GDPgfAYMZ\
# CRbMR8BgRn4yhPkIGMzoYf85YNvNcfV0sJXBKUxjjLH0EFByzsvbfTzhezdzFaIzNRR53zK38pek\
# mwlY+UXistjA4DL4DwyAJAEDIEnAAEgSMACSBAyAJAEDIEnAAEi6mXNgcCrOZsFlsIEBkCRgACQJ\
# GABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRg\
# ACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoAB\
# kCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZA\
# koABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJ\
# AgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJGABJAgZAkoABkCRgACQJ\
# GABJAgZAkoABkPQKqkcogDHXn4cAAAAASUVORK5CYII=\
# "
#   frames[1] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAABMpJREFUeJzt2+1Jw1AYgFEjncI1nMM16kx2Ded

# %%
from collections import defaultdict
nact = 1
values = defaultdict(lambda: [0.1]*nact)
print(values[1][0])

print(max(range(nact), key = lambda act: values[state][act]))
#(range(nact), key = lambda act: values[state][act])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49f56147506c> in <module>
#       2 nact = 1
#       3 values = defaultdict(lambda: [0.1]*nact)
# ----> 4 print(values[state][0])
#       5
#       6 print(max(range(nact), key = lambda act: values[state][act]))
#
# NameError: name 'state' is not defined
